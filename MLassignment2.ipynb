# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sas

# %%
data=pd.read_csv('Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          225     Spain  Female   41
# 2          3    15619304      Onio          629    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
sas.distplot(data.EstimatedSalary)

# %%
sas.boxplot(data.EstimatedSalary)

# %%
data.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F504DC8F60>,
# ...
#       dtype=object)

# %%
sas.barplot(y=data.EstimatedSalary,x=data.Geography)

# %%
sas.pairplot(data)

# %%
data.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.006658  0.000519 -0.006495
# CustomerId        0.004202    1.000000     0.005701  0.009288 -0.014883
# CreditScore       0.006658    0.005701     1.000000 -0.004171  0.001382
# Age               0.000519    0.009288    -0.004171  1.000000 -0.010156
# Tenure           -0.006495   -0.014883     0.001382 -0.010156  1.000000
# Balance          -0.009157   -0.012362     0.006584  0.028412 -0.012236
# NumOfProducts     0.007246    0.016972     0.012753 -0.030821  0.013444
# HasCrCard         0.000599   -0.014025    -0.004893 -0.011623  0.022583
# IsActiveMember    0.012044    0.001665     0.024910  0.085625 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001109 -0.007277  0.007784
# Exited           -0.016571   -0.006248    -0.026509  0.285262 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
hm=data.corr()
sas.heatmap(hm)

# %%
sas.scatterplot(data.EstimatedSalary,data.Geography)

# %%
data.describe()
# Out:
#          RowNumber    CustomerId  CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.00000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.48290     38.923400      5.012800
# std     2886.89568  7.193619e+04     96.72014     10.487208      2.892174
# min        1.00000  1.556570e+07    225.00000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.00000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.00000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    717.25000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.00000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76489.148004       1.530200      0.70550        0.515100
# std     62399.589585       0.581654      0.45584        0.499797
# ...

# %%
data.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
sas.boxplot(data.CreditScore)

# %%
perc99=data.CreditScore.quantile(0.25)
perc99
# Out:
# 584.0

# %%
data=data[data.CreditScore>=perc99]
sas.boxplot(data.CreditScore)

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data.columns[0]
# Out:
# 'RowNumber'

# %%
data.columns[2]
# Out:
# 'Surname'

# %%
data.columns[13]
# Out:
# 'Exited'

# %%
sas.boxplot(data.EstimatedSalary)

# %%
data.Geography.value_counts()
# Out:
# France     3732
# Germany    1893
# Spain      1884
# Name: Geography, dtype: int64

# %%
data.Gender.value_counts()
# Out:
# Male      4080
# Female    3429
# Name: Gender, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.Geography=(le.fit_transform(data.Geography))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619          0  Female   42
# 2          3    15619304      Onio          629          0  Female   42
# 3          4    15701354      Boni          699          0  Female   39
# 4          5    15737888  Mitchell          850          2  Female   43
# 5          6    15574012       Chu          645          2    Male   44
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# ...

# %%
x=data.iloc[:,3:12].values
y=data.iloc[:,13:14].values

# %%
x
# Out:
# array([[619, 0, 'Female', ..., 1, 1, 1],
#        [629, 0, 'Female', ..., 3, 1, 0],
#        [699, 0, 'Female', ..., 2, 0, 0],
#        ...,
#        [709, 0, 'Female', ..., 1, 0, 1],
#        [772, 1, 'Male', ..., 2, 1, 0],
#        [792, 0, 'Female', ..., 1, 1, 0]], dtype=object)

# %%
y
# Out:
# array([[1],
#        [1],
#        [0],
#        ...,
#        [1],
#        [1],
#        [0]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[643, 0, 'Female', ..., 1, 1, 1],
#        [850, 0, 'Male', ..., 1, 1, 1],
#        [600, 2, 'Male', ..., 1, 1, 1],
#        ...,
#        [733, 2, 'Female', ..., 1, 1, 1],
#        [850, 0, 'Female', ..., 1, 1, 0],
#        [751, 1, 'Female', ..., 1, 1, 1]], dtype=object)

# %%
x_test
# Out:
# array([[639, 2, 'Female', ..., 1, 1, 1],
#        [605, 2, 'Male', ..., 1, 0, 0],
#        [598, 2, 'Male', ..., 2, 1, 1],
#        ...,
#        [713, 1, 'Female', ..., 1, 1, 1],
#        [750, 2, 'Female', ..., 2, 0, 0],
#        [697, 0, 'Female', ..., 2, 1, 0]], dtype=object)

# %%
y_train
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
y_test
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]], dtype=int64)
